# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Vérification rapide

# %%
df = pd.read_excel("../data/Online_Retail.xlsx")

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
# Vérification des valeurs nulles
df.isnull().sum()
